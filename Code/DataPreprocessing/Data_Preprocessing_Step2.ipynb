# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import shutil
import pandas as pd

# %%
# !unzip '/content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/plant-pathology-2021-fgvc8.zip' -d '/content/drive/MyDrive/1:1_Hanish_Acharla/Dataset'
# Out:
# Archive:  /content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/plant-pathology-2021-fgvc8.zip
# replace /content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/sample_submission.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/sample_submission.csv
# replace /content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/test_images/85f8cb619c66b863.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/test_images/85f8cb619c66b863.jpg
# replace /content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/test_images/ad8770db05586b59.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/test_images/ad8770db05586b59.jpg
# replace /content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/test_images/c7b03e718489f3ca.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/test_images/c7b03e718489f3ca.jpg
# ...

# %%
# Path to the directory containing the images
image_dir = '/content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/train_images'
# Path to the directory where you want to create the folders
output_dir = '/content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/Dataset_Splitted'
# Path to the CSV file containing the image-to-split mapping
csv_file = '/content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/Train_Modified.csv'
# Load the CSV file into a DataFrame
splits = pd.read_csv(csv_file)

# %%
# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)
# Create folders for each split and move the images
for _, row in splits.iterrows():
    image_name = row['image']  # Column name for image filenames
    split = row['split']  # Column name for split
    # Create the split directory if it doesn't exist
    split_dir = os.path.join(output_dir, split)
    os.makedirs(split_dir, exist_ok=True)
    # Move the image to the corresponding split folder
    src_path = os.path.join(image_dir, image_name)
    dest_path = os.path.join(split_dir, image_name)
    # Check if the source image file exists before moving
    if os.path.exists(src_path):
        shutil.move(src_path, dest_path)
print("Images have been organized into separate folders for each split.")
# Out:
# Images have been organized into separate folders for each split.

# %%
# Path to the directory containing the test images
image_dir = '/content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/Dataset_Splitted/Train'
# Path to the directory where you want to create the folders
output_dir = '/content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/Final_Dataset/Train'
# Path to the CSV file containing the image-to-label mapping
csv_file = '/content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/Train_Modified.csv'
# Load the CSV file into a DataFrame
labels = pd.read_csv(csv_file)

# %%
# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)
# Create folders for each label and move the images
for _, row in labels.iterrows():
    image_name = row['image']  # Column name for image filenames
    label = row['labels']  # Column name for labels
    # Create the label directory if it doesn't exist
    label_dir = os.path.join(output_dir, label)
    os.makedirs(label_dir, exist_ok=True)
    # Move the image to the corresponding label folder
    src_path = os.path.join(image_dir, image_name)
    dest_path = os.path.join(label_dir, image_name)
    # Check if the source image file exists before moving
    if os.path.exists(src_path):
        shutil.move(src_path, dest_path)

# %%
# Path to the directory containing the test images
image_dir = '/content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/Dataset_Splitted/Test'
# Path to the directory where you want to create the folders
output_dir = '/content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/Final_Dataset/Test'
# Path to the CSV file containing the image-to-label mapping
csv_file = '/content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/Train_Modified.csv'
# Load the CSV file into a DataFrame
labels = pd.read_csv(csv_file)

# %%
# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)
# Create folders for each label and move the images
for _, row in labels.iterrows():
    image_name = row['image']  # Column name for image filenames
    label = row['labels']  # Column name for labels
    # Create the label directory if it doesn't exist
    label_dir = os.path.join(output_dir, label)
    os.makedirs(label_dir, exist_ok=True)
    # Move the image to the corresponding label folder
    src_path = os.path.join(image_dir, image_name)
    dest_path = os.path.join(label_dir, image_name)
    # Check if the source image file exists before moving
    if os.path.exists(src_path):
        shutil.move(src_path, dest_path)

# %%
# Path to the directory containing the test images
image_dir = '/content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/Dataset_Splitted/Validation'
# Path to the directory where you want to create the folders
output_dir = '/content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/Final_Dataset/Validation'
# Path to the CSV file containing the image-to-label mapping
csv_file = '/content/drive/MyDrive/1:1_Hanish_Acharla/Dataset/Train_Modified.csv'
# Load the CSV file into a DataFrame
labels = pd.read_csv(csv_file)

# %%
# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)
# Create folders for each label and move the images
for _, row in labels.iterrows():
    image_name = row['image']  # Column name for image filenames
    label = row['labels']  # Column name for labels
    # Create the label directory if it doesn't exist
    label_dir = os.path.join(output_dir, label)
    os.makedirs(label_dir, exist_ok=True)
    # Move the image to the corresponding label folder
    src_path = os.path.join(image_dir, image_name)
    dest_path = os.path.join(label_dir, image_name)
    # Check if the source image file exists before moving
    if os.path.exists(src_path):
        shutil.move(src_path, dest_path)
